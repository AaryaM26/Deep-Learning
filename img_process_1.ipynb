# %%
# getting an image using web get

# !wget 'https://www.google.com/url?sa=i&url=https%3A%2F%2Fpixabay.com%2Fillustrations%2Fai-generated-astronaut-space-7734317%2F&psig=AOvVaw1qmhg1LQnOZIyqRi0Mq03w&ust=1692253228383000&source=images&cd=vfe&opi=89978449&ved=0CBAQjRxqFwoTCMD_0tXE4IADFQAAAAAdAAAAABAF'
# Out:
# --2023-08-16 07:57:31--  https://www.google.com/url?sa=i&url=https%3A%2F%2Fpixabay.com%2Fillustrations%2Fai-generated-astronaut-space-7734317%2F&psig=AOvVaw1qmhg1LQnOZIyqRi0Mq03w&ust=1692253228383000&source=images&cd=vfe&opi=89978449&ved=0CBAQjRxqFwoTCMD_0tXE4IADFQAAAAAdAAAAABAF
# Resolving www.google.com (www.google.com)... 172.253.62.99, 172.253.62.103, 172.253.62.104, ...
# Connecting to www.google.com (www.google.com)|172.253.62.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘url?sa=i&url=https:%2F%2Fpixabay.com%2Fillustrations%2Fai-generated-astronaut-space-7734317%2F&psig=AOvVaw1qmhg1LQnOZIyqRi0Mq03w&ust=1692253228383000&source=images&cd=vfe&opi=89978449&ved=0CBAQjRxqFwoTCMD_0tXE4IADFQAAAAAdAAAAABAF.3’
#
# url?sa=i&url=https:     [ <=>                ]   1.50K  --.-KB/s    in 0s
#
# ...

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/ai-generated-7734317_1280.jpg')#reads the image and stores in img

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape #width x height
# Out:
# (1280, 853, 3)

# %%
print(img.shape)
# Out:
# (1280, 853, 3)

# %%
print(img)
# Out:
# [[[  5   3   4]
#   [  5   3   4]
#   [  5   3   4]
#   ...
#   [  3   1   2]
#   [  3   1   2]
#   [  3   1   2]]
#
#  [[  5   3   4]
#   [  5   3   4]
#   [  4   2   3]
#   ...
#   [  3   1   2]
#   [  3   1   2]
#   [  3   1   2]]
#
#  [[  4   2   3]
#   [  4   2   3]
#   [  4   2   3]
#   ...
#   [  3   1   2]
#   [  3   1   2]
#   [  3   1   2]]
#
#  ...
#
#  [[  8   3   0]
#   [  6   2   0]
#   [  7   2   0]
#   ...
#   [117 234 252]
#   [115 232 250]
#   [114 229 248]]
#
#  [[  6   1   5]
#   [  4   2   5]
#   [  5   0   4]
#   ...
#   [117 234 252]
#   [116 233 251]
#   [114 229 248]]
#
#  [[  4   2   7]
#   [  3   1   6]
#   [  3   1   6]
#   ...
#   [118 235 253]
#   [116 233 251]
#   [115 230 249]]]

# %%
#displaying image from numpy array
img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img = Image.open('/content/ai-generated-7734317_1280.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('spaceart.jpg')

# %%
img_res = mpimg.imread('/content/spaceart.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
#openCV for computer vision tasks

# %%
import cv2

# %%
img=cv2.imread('/content/ai-generated-7734317_1280.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# convert to greyscale

# %%
img.shape
# Out:
# (1280, 853, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1280, 853)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=853x1280>

# %%
cv2.imwrite('astraunaut_grayscale_image.jpg', grayscale_image)
# Out:
# True
